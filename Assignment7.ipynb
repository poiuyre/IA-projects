# %% [markdown]
# Assignment 7

# %%
data = {
    "hello": "Hello! How can I assist you?",
    "hey": "Hello! How can I assist you?",
    "hi": "Hello! How can I assist you?",
    "goodbye": "Goodbye! Have a great day!",
    "bye": "Goodbye! Have a great day!",
    "greetings": "Hey there! How can I help you today?",
    "farewell": "Goodbye! Have a wonderful day ahead!",
    "weather": "The weather is sunny today.",
    "news": "Here are the latest news headlines...",
    "help": "Sure, I'm here to help. What do you need assistance with?",
    "database": "I'm sorry, I don't have access to the database.",
    "time": "The current time is 10:00 AM.",
    "date": "Today's date is March 4, 2024.",
    "calendar": "Your calendar is empty for today.",
    "reminder": "You have no upcoming reminders.",
    "assistance": "I'm here to assist you. What do you need help with?",
    "bus": "The next bus to downtown arrives in 10 minutes.",
    "train": "The train to the city center departs at 9:30 AM.",
    "tram": "The tram service operates every 15 minutes during peak hours.",
    "restaurant": "There's a great Italian restaurant nearby called 'La Trattoria'.",
    "pizzeria": "Try out the new pizzeria 'Pizza Italia' for delicious slices.",
    "sushi": "Craving sushi? Head over to 'Sakura Sushi' for the freshest fish in town.",
    "exit": "",

    ("no","access"): "Apologies, I'm unable to access that information at the moment.",
    ("current","time"): "It's currently 10:00 AM.",
    ("current","date"): "Today's date is March 4, 2024.",
    ("empty","calendar"): "You don't have any events scheduled for today.",
    ("no", "reminder"): "You don't have any upcoming reminders.",
    ("current","weather"): "The current weather is sunny and clear.",
    ("latest","updates"): "Here are the latest updates from around the world...",
    ("tomorrow", "weather"): "The weather forecast for tomorrow is partly cloudy.",
    ("yesterday", "weather"): "Yesterday's forecast was partly cloudy skies.",
    ("meeting", "schedule"): "Let's schedule the meeting for tomorrow at 2:00 PM.",
    ("news", "today"): "Here are today's top news stories...",
    ("news", "yesterday"): "Here are yesterday's top news headlines...",
    ("reminder", "create"): "Reminder created successfully for tomorrow's meeting.",
    ("bus", "schedule"): "The bus schedule for Route 5 is as follows: 7:00 AM, 8:30 AM, 10:00 AM, 11:30 AM...",
    ("tren", "schedule"): "The train schedule for the suburban line is available at www.example.com.",
    ("tranvía", "schedule"): "Tram services run from 6:00 AM to 10:00 PM daily.",
    ("restaurant", "recommend"): "For a romantic dinner, I recommend 'Café Rouge'.",
    ("restaurant", "recommendation"): "I highly recommend 'Gourmet Grill' for a memorable dining experience.",
    ("pizzeria", "menu"): "Pizza Italia offers a variety of pizzas including Margherita, Pepperoni, and Hawaiian.",
    ("pizza", "menu"): "Pizza Palace offers a variety of pizzas including Margherita, Pepperoni, and Vegetarian.",
    ("sushi", "menu"): "Sakura Sushi's menu features classic rolls like California, Spicy Tuna, and Dragon Roll.",
    ("bus", "today"): "No disruptions reported on the bus schedule for today.",
    ("train", "today"): "Please be advised of scheduled maintenance on the train line today.",
    ("tram", "today"): "Expect minor delays on the tram service due to heavy traffic.",
    ("restaurant", "reservation"): "I've made a reservation for you at Bella Vista for tonight at 7:00 PM.",
    ("pizza", "order"): "You can place your pizza order at Pizza Palace by calling +123456789.",
    ("sushi", "delivery"): "Sushi Delight offers home delivery within a 5-mile radius. Order now!",
    ("thank", "you"): "You're welcome! If you need anything else, feel free to ask.",
    ("error",): "Oops! Something went wrong. Please try again later.",
    ("today", "forecast"): "Today's weather forecast calls for clear skies and mild temperatures.",
    ("local", "events"): "Check out the local events happening near you...",
    ("guidance",): "I'm here to provide guidance. What do you need assistance with?",
    ("access", "denied"): "Access denied. You do not have permission to view this information.",
    ("time", "check"): "The current time is 12:30 PM.",
    ("date", "check"): "Today's date is March 5, 2024.",
    ("busy", "schedule"): "Your schedule seems packed today. Remember to take breaks!",
    ("upcoming", "reminder"): "You have a reminder set for today's meeting at 3:00 PM.",
    ("tomorrow", "forecast"): "Tomorrow's weather forecast predicts scattered showers in the afternoon.",
    ("yesterday", "forecast"): "Yesterday's weather was mostly sunny with a slight breeze.",
    ("schedule", "confirmed"): "Your meeting for tomorrow has been successfully scheduled at 10:00 AM.",
    ("recent", "news"): "Stay updated with the latest news from around the globe...",
    ("evening", "bus"): "The next bus to downtown arrives in 15 minutes.",
    ("morning", "train"): "The morning train to the city center departs at 8:00 AM sharp.",
    ("night", "tram"): "Tram services operate until midnight tonight.",
    ("bus", "routes"): "Explore different bus routes available in the city...",
    ("train", "services"): "Learn more about the various train services offered...",
    ("tram", "routes"): "Discover the tram routes that cover different areas of the city...",
    ("new", "restaurant"): "Check out the new restaurant 'Le Petit Café' for a cozy dining experience.",
    ("burger", "joint"): "If you're craving burgers, 'Burger Haven' is the place to go.",
    ("vegetarian", "cuisine"): "For delicious vegetarian options, try 'Green Leaf Restaurant'.",
    ("fine", "dining"): "Indulge in fine dining at 'The Chef's Table' for an exquisite culinary experience.",
    ("restaurant", "specials"): "Explore the daily specials offered at your favorite restaurants...",
    ("pizza", "toppings"): "Customize your pizza with a variety of toppings available...",
    ("sushi", "platters"): "Order sushi platters for your next gathering from 'Sushi Supreme'.",
    ("dessert", "menu"): "Don't forget to check out the dessert menu for some sweet treats...",
    ("bus", "delays"): "Please expect delays on several bus routes due to heavy traffic.",
    ("train", "maintenance"): "Train services may experience delays today due to maintenance works.",
    ("tram", "announcement"): "Attention passengers, tram services are temporarily suspended on Route 3.",
    ("restaurant", "feedback"): "Share your feedback on your dining experience and help us improve...",
    ("pizza", "feedback"): "We value your feedback on our pizza quality and service...",
    ("sushi", "feedback"): "Let us know how we're doing in serving you the best sushi in town...",
    ("daily", "forecast"): "Stay informed with the daily weather forecast for your area.",
    ("global", "updates"): "Get the latest global updates on current affairs and events.",
    ("customer", "service"): "Our customer service team is available 24/7 to assist you.",
    ("data", "privacy"): "We prioritize data privacy and security in all our services.",
    ("planning", "session"): "Let's plan your session for tomorrow afternoon at 3:00 PM.",
    ("breaking", "news"): "Stay tuned for breaking news updates as they happen.",
    ("event", "reminder"): "Don't forget to set a reminder for the upcoming event.",
    ("transport", "options"): "Explore different transportation options available in your area.",
    ("health", "inspection"): "Our restaurants undergo regular health inspections to ensure safety.",
    ("new", "menu"): "Check out our new menu items for a fresh dining experience.",
    ("delivery", "service"): "Enjoy the convenience of our delivery service for your favorite meals.",
    ("bus", "route"): "Discover the scenic route on our bus tour around the city.",
    ("train", "line"): "Explore the different train lines that connect major destinations.",
    ("tram", "route"): "Plan your journey with ease using our interactive tram route map.",
    ("reservation", "confirmation"): "Your reservation at our restaurant is confirmed for tonight.",
    ("order", "tracking"): "Track your order status in real-time for a hassle-free experience.",
    ("special", "offer"): "Don't miss out on our special offer - limited time only!",
    ("customer", "feedback"): "We value your feedback to improve our services. Share your thoughts with us.",
    ("loyalty", "program"): "Join our loyalty program and enjoy exclusive perks and rewards.",
    ("delivery", "notification"): "Receive instant notifications on your delivery status for peace of mind.",
    ("menu", "recommendation"): "Our chef's recommendation for today is our signature dish - try it now!",
}

# %%
def get_response(user_input):
    #define variables to solve the problem of tuples
    individual_response = None
    tuple_response = None
    for key, response in data.items():
        if isinstance(key, tuple):
            all_keywords_present = all((keyword is None or keyword in user_input) for keyword in key)
            if all_keywords_present:
                tuple_response = response
        elif key is not None and key in user_input:
            individual_response = response
            #priority + default response
    return tuple_response if tuple_response is not None else individual_response or "Sorry, I'm not sure how to help with that."

# %%
print("Assistant: Hello! How can I assist you?")
while True:
    user_input = input("You: ")
    response = get_response(user_input)
    print("Assistant:", response)
    if user_input.lower() == "exit":
        print("Assistant: Goodbye!")
        break
# Out:
# Assistant: Hello! How can I assist you?
# You: hi
# Assistant: Hello! How can I assist you?
# You: how about the weather for today
# Assistant: The weather is sunny today.
# You: and the weather for tomorrow
# Assistant: The weather forecast for tomorrow is partly cloudy.
# You: and what about the weather for yesterday
# Assistant: Yesterday's forecast was partly cloudy skies.
# You: thank you
# Assistant: You're welcome! If you need anything else, feel free to ask.
# You: exit
# Assistant: Sorry, I'm not sure how to help with that.
# Assistant: Goodbye!
